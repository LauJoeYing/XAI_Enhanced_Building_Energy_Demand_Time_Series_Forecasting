# %%
import numpy as np , pandas as pd

# %%
# %pip install data_fetcher
# Out:
# Requirement already satisfied: data_fetcher in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (0.1.8.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ccxt in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from data_fetcher) (4.3.21)
# Requirement already satisfied: pandas in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from data_fetcher) (1.5.3)
# Requirement already satisfied: numpy in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from data_fetcher) (1.25.2)
# Requirement already satisfied: alpaca-trade-api in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from data_fetcher) (3.2.0)
# Requirement already satisfied: alpaca-py in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from data_fetcher) (0.21.0)
# Requirement already satisfied: python-dateutil in c:\users\joeyi\appdata\roaming\python\python311\site-packages (from data_fetcher) (2.8.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py->data_fetcher) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py->data_fetcher) (2.7.1)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py->data_fetcher) (2.30.0)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py->data_fetcher) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-py->data_fetcher) (10.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from pandas->data_fetcher) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil->data_fetcher) (1.16.0)
# Requirement already satisfied: urllib3<2,>1.24 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-trade-api->data_fetcher) (1.26.18)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-trade-api->data_fetcher) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-trade-api->data_fetcher) (3.9.5)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-trade-api->data_fetcher) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from alpaca-trade-api->data_fetcher) (2.1.0)
# Requirement already satisfied: packaging in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api->data_fetcher) (23.1)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (65.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (2023.5.7)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (42.0.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (4.9.0)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from ccxt->data_fetcher) (1.9.4)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from aiodns>=1.1.1->ccxt->data_fetcher) (4.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api->data_fetcher) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api->data_fetcher) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api->data_fetcher) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api->data_fetcher) (6.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=2.6.1->ccxt->data_fetcher) (1.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py->data_fetcher) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py->data_fetcher) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py->data_fetcher) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py->data_fetcher) (3.4)
# Requirement already satisfied: pycparser in c:\users\joeyi\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt->data_fetcher) (2.21)

# %%
data = pd.read_csv('D:/Downloads/final-year-project/data/preprocessed_train_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  building_id  meter            timestamp  meter_reading  \
# 0      146446            7      1  2016-02-29 09:00:00       1857.260
# 1      146449            9      1  2016-02-29 09:00:00        590.945
# 2      146454           13      1  2016-02-29 09:00:00       1224.100
# 3      146456           14      1  2016-02-29 09:00:00       1435.150
# 4      146458           15      1  2016-02-29 09:00:00        422.104
#
#    site_id  primary_use  square_feet  air_temperature  cloud_coverage  \
# 0        0            0       121074             12.8             NaN
# 1        0            6        27000             12.8             NaN
# 2        0            0        99380             12.8             NaN
# 3        0            0        86250             12.8             NaN
# 4        0            6        83957             12.8             NaN
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0              8.9                0.0              1021.9             0.0
# 1              8.9                0.0              1021.9             0.0
# 2              8.9                0.0              1021.9             0.0
# 3              8.9                0.0              1021.9             0.0
# 4              8.9                0.0              1021.9             0.0
#
#    wind_speed  day  month  hour
# 0         0.0   29      2     9
# 1         0.0   29      2     9
# 2         0.0   29      2     9
# 3         0.0   29      2     9
# 4         0.0   29      2     9

# %%
from sklearn.preprocessing import MinMaxScaler 
from data_fetcher import Fetcher
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer


fetcher= Fetcher() # to clean the data
data_cleaned= fetcher.transform(data)

numerical_pipeline = Pipeline([ ('imputer', SimpleImputer()), # to fill missing values with mean
                                ('scaler', MinMaxScaler())
                              ])

num_attribs = ['meter_reading','air_temperature','dew_temperature','sea_level_pressure','wind_direction','wind_speed'] # columns to transform
date_attribs=['day','month'	,'hour']

full_pipeline = ColumnTransformer([ ("num", numerical_pipeline, num_attribs),
                                      ("date", SimpleImputer() ,  date_attribs )])

transformed_data = full_pipeline.fit_transform(data_cleaned)
# Out:
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['building_id', 'meter', 'primary_use'],
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "timestamp"] = pd.to_datetime(df.loc[:, "timestamp"])
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['season'] = df.month.apply(self.season_finder)
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekend'] = df.timestamp.dt.dayofweek > 4
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_the_week'] = df.timestamp.dt.dayofweek

# %%
tmp_cols=['meter_reading','air_temperature','dew_temperature','sea_level_pressure','wind_direction','wind_speed', 'day','month','hour']

# %%
transformed_data
# Out:
# array([[ 0.        ,  0.20923913,  0.38175676, ...,  1.        ,
#          1.        ,  0.        ],
#        [ 0.36463482,  0.20652174,  0.38175676, ...,  1.        ,
#          1.        ,  1.        ],
#        [ 0.36902801,  0.17663043,  0.36486486, ...,  1.        ,
#          1.        ,  2.        ],
#        ...,
#        [ 0.2800659 ,  0.29347826,  0.49662162, ..., 31.        ,
#         12.        , 21.        ],
#        [ 0.27594728,  0.29347826,  0.51013514, ..., 31.        ,
#         12.        , 22.        ],
#        [ 0.27841845,  0.30978261,  0.52027027, ..., 31.        ,
#         12.        , 23.        ]])

# %%
pd.DataFrame(transformed_data , index=data_cleaned.index , columns= tmp_cols )
# Out:
#                      meter_reading  air_temperature  dew_temperature  \
# timestamp
# 2016-01-01 00:00:00       0.000000         0.209239         0.381757
# 2016-01-01 01:00:00       0.364635         0.206522         0.381757
# 2016-01-01 02:00:00       0.369028         0.176630         0.364865
# 2016-01-01 03:00:00       0.366282         0.160326         0.341216
# 2016-01-01 04:00:00       0.366557         0.168478         0.361486
# ...                            ...              ...              ...
# 2016-12-31 19:00:00       0.292696         0.326087         0.520270
# 2016-12-31 20:00:00       0.285283         0.301630         0.506757
# 2016-12-31 21:00:00       0.280066         0.293478         0.496622
# 2016-12-31 22:00:00       0.275947         0.293478         0.510135
# 2016-12-31 23:00:00       0.278418         0.309783         0.520270
#
#                      sea_level_pressure  wind_direction  wind_speed   day  \
# timestamp
# 2016-01-01 00:00:00            0.659280        0.666667    0.167568   1.0
# 2016-01-01 01:00:00            0.668975        0.638889    0.140541   1.0
# 2016-01-01 02:00:00            0.673130        0.000000    0.000000   1.0
# 2016-01-01 03:00:00            0.678670        0.472222    0.081081   1.0
# 2016-01-01 04:00:00            0.684211        0.305556    0.081081   1.0
# ...                                 ...             ...         ...   ...
# 2016-12-31 19:00:00            0.750693        0.611111    0.194595  31.0
# 2016-12-31 20:00:00            0.742382        0.611111    0.221622  31.0
# 2016-12-31 21:00:00            0.732687        0.611111    0.248649  31.0
# 2016-12-31 22:00:00            0.721607        0.527778    0.167568  31.0
# 2016-12-31 23:00:00            0.711911        0.583333    0.308108  31.0
#
#                      month  hour
# timestamp
# 2016-01-01 00:00:00    1.0   0.0
# 2016-01-01 01:00:00    1.0   1.0
# 2016-01-01 02:00:00    1.0   2.0
# 2016-01-01 03:00:00    1.0   3.0
# 2016-01-01 04:00:00    1.0   4.0
# ...                    ...   ...
# 2016-12-31 19:00:00   12.0  19.0
# 2016-12-31 20:00:00   12.0  20.0
# 2016-12-31 21:00:00   12.0  21.0
# 2016-12-31 22:00:00   12.0  22.0
# 2016-12-31 23:00:00   12.0  23.0
#
# [8763 rows x 9 columns]

# %%
import numpy as np , pandas as pd 
from sklearn.base import BaseEstimator, TransformerMixin

class Do_nothing(BaseEstimator, TransformerMixin):
    
    def __init__(self): # 99 referes to none
        return 
        
    def fit(self, x, y=None):
        return self  # nothing else to do
    
    
    def transform(self, x):
        return x.astype(int)

# %%
from sklearn.preprocessing import MinMaxScaler 
from data_fetcher import Fetcher
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer


fetcher= Fetcher() # to clean the data
data_cleaned= fetcher.transform(data)

numerical_pipeline = Pipeline([ ('imputer', SimpleImputer()), # to fill missing values with mean
                                ('scaler', MinMaxScaler())
                              ])

num_attribs = ['meter_reading','air_temperature','dew_temperature','sea_level_pressure','wind_direction','wind_speed'] # columns to transform
date_attribs=['day','month'	,'hour', 'season', 'weekend', 'day_of_the_week']

full_pipeline = ColumnTransformer([ ("num", numerical_pipeline, num_attribs),
                                      ("date", Do_nothing() ,  date_attribs )])
# Out:
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['building_id', 'meter', 'primary_use'],
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "timestamp"] = pd.to_datetime(df.loc[:, "timestamp"])
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['season'] = df.month.apply(self.season_finder)
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekend'] = df.timestamp.dt.dayofweek > 4
# d:\Downloads\final-year-project\notebooks\data_fetcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_the_week'] = df.timestamp.dt.dayofweek

# %%
transformed_data = full_pipeline.fit_transform(data_cleaned)
pd.DataFrame(transformed_data , index=data_cleaned.index , columns= data_cleaned.columns ).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 transformed_data = full_pipeline.fit_transform(data_cleaned)
# ----> 2 pd.DataFrame(transformed_data , index=data_cleaned.index , columns= data_cleaned.columns ).head()
#
# File c:\Users\joeyi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:722, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     712         mgr = dict_to_mgr(
#     713             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     714             # attribute "name"
#    (...)
#     719             typ=manager,
#     720         )
#     721     else:
# --> 722         mgr = ndarray_to_mgr(
#     723             data,
#     724             index,
#     725             columns,
#     726             dtype=dtype,
#     727             copy=copy,
#     728             typ=manager,
#     729         )
#     731 # For data is list-like, or Iterable (will consume into list)
#     732 elif is_list_like(data):
#
# File c:\Users\joeyi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:349, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     345 index, columns = _get_axes(
#     346     values.shape[0], values.shape[1], index=index, columns=columns
#     347 )
# --> 349 _check_values_indices_shape_match(values, index, columns)
#     351 if typ == "array":
#     353     if issubclass(values.dtype.type, str):
#
# File c:\Users\joeyi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (8763, 12), indices imply (8763, 13)
